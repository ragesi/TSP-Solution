# %%
import matplotlib
import matplotlib.pyplot as plt
import math as m
from scipy.spatial import ConvexHull
import numpy as np

# 此处是一个jupyter notebook的魔术命令，用于在Notebook中启用交互式的Matplotlib绘图
# %matplotlib notebook

# 设置Matplotlib的全局参数，将动画的渲染方式设置为JavaScript HTML。
plt.rcParams['animation.html'] = 'jshtml'

# %matplotlib inline

# %%
file_path = r'..\dataset\38\dj38.tsp'

with open(file_path, 'r') as file:
    lines = file.readlines()

lines = lines[10: -1]
points = list()
for line in lines:
    tmp_point = line.strip().split(' ')
    tmp_point = [float(x) for x in tmp_point]
    tmp_point[0] = int(tmp_point[0])
    points.append([tmp_point[1], tmp_point[2]])
    
point_num = len(points)

hull = ConvexHull(points)
    
x_values = [points[i][0] for i in range(len(points)) if i in hull.vertices]
y_values = [points[i][1] for i in range(len(points)) if i in hull.vertices]
plt.scatter(x_values, y_values, marker='o', color='r', s=10)

x_values = [points[i][0] for i in range(len(points)) if i not in hull.vertices]
y_values = [points[i][1] for i in range(len(points)) if i not in hull.vertices]
plt.scatter(x_values, y_values, marker='o', color='b', s=10)

x_values = [points[hull.vertices[i]][0] for i in range(-1, len(hull.vertices))]
y_values = [points[hull.vertices[i]][1] for i in range(-1, len(hull.vertices))]

plt.plot(x_values, y_values, color='grey')  # 绘制边框

plt.show()

# %%
file_path = r'..\dataset\16\ulysses16.tsp'

with open(file_path, 'r') as file:
    lines = file.readlines()

lines = lines[7: -1]
points = list()
for line in lines:
    tmp_point = line.strip().split(' ')
    tmp_point = [float(x) for x in tmp_point]
    tmp_point[0] = int(tmp_point[0])
    points.append([tmp_point[1], tmp_point[2]])
    
point_num = len(points)

hull = ConvexHull(points)
    
x_values = [points[i][0] for i in range(len(points)) if i in hull.vertices]
y_values = [points[i][1] for i in range(len(points)) if i in hull.vertices]
plt.scatter(x_values, y_values, marker='o', color='r', s=15)

x_values = [points[i][0] for i in range(len(points)) if i not in hull.vertices]
y_values = [points[i][1] for i in range(len(points)) if i not in hull.vertices]
plt.scatter(x_values, y_values, marker='o', color='b', s=15)

# for tmp_i in range(1, len(hull.vertices) + 1):
for tmp_i in range(1, 4):
    i = tmp_i % len(hull.vertices)
    j = (i + 1) % len(hull.vertices)
    plt.plot([points[hull.vertices[i]][0], points[hull.vertices[j]][0]],
            [points[hull.vertices[i]][1], points[hull.vertices[j]][1]], color='grey')
    if i == 1:
        plt.plot([points[hull.vertices[i]][0], points[hull.vertices[i]][0] + 5],
                [points[hull.vertices[i]][1], points[hull.vertices[i]][1]], 
                linestyle='--', color='grey')

    delta_y = 5 if points[hull.vertices[j]][1] > points[hull.vertices[i]][1] else -5
    delta_x = delta_y * (points[hull.vertices[j]][0] - points[hull.vertices[i]][0]) / (
        points[hull.vertices[j]][1] - points[hull.vertices[i]][1])
    length = np.linalg.norm([delta_x, delta_y])
    delta_x = delta_x / length * 8
    delta_y = delta_y / length * 8
    plt.plot([points[hull.vertices[j]][0], points[hull.vertices[j]][0] + delta_x],
            [points[hull.vertices[j]][1], points[hull.vertices[j]][1] + delta_y], 
            linestyle='--', color='grey')

# plt.plot([36.08, 41.08], [-5.21, -5.21], linestyle='--', color='grey')
# plt.plot([36.08, 41.23], [-5.21, 9.10], color='grey')
# plt.plot([41.23, 44.23], [9.10, 17.4359], linestyle='--', color='grey')
# plt.plot([41.23, 41.17], [9.10, 13.05], color='grey')
# plt.plot([41.17, 41.018], [13.05, 23.05], linestyle='--', color='grey')
# plt.plot([41.17, 40.56], [13.05, 25.32], color='grey')

plt.show()

# %%
""" QOPSA算法和GQ-TSP算法的量子比特使用量的曲线图 此处比较的都是计算N个节点的哈密顿回路"""

# QOPSA: (N-1) * \lceil log(N-1) \rceil + max(N-1, 6) + 6 + 2
# GQ-TSP: N * \lceil logN \rceil + 2 \sqrt N logN + 

def find_divisors(n):
    num_divisor = 0
    for i in range(1, n):
        if n % i == 0:
            num_divisor += 1
    return num_divisor

p = 6

x = []
mine_y = []
others_y = []
N = 30
for i in range(4, N + 1):
    x.append(i)
    mine_y.append( (i - 1) * m.ceil(m.log2(i - 1)) + max(i - 1, p) + max(i - 3, p - 1) + 3 )

    # 求共需要几个寄存器来作为Location register和Anchor register
    n = m.ceil(m.log2(i))
    tmp_LR = 1000
    for k in range(1, i):
        tmp_LR = min(tmp_LR, m.floor(i / (k + 1)) + k)

    tmp_y = n * tmp_LR + n + find_divisors(i)
    if tmp_y < 13:
        tmp_y = 13
        
    others_y.append( i * n + tmp_y + 2 )
    if n > 2:
        others_y[i - 4] += n - 2

# print(mine_y)
# print(others_y)

# %matplotlib inline

plt.plot(x, mine_y, linestyle='-', linewidth=1, color='orange', label='QOPSA')
plt.plot(x, others_y, linestyle='-', linewidth=1, color='blue', label='GQ-TSP')

plt.legend(['QOPSA', 'GQ-TSP'])
plt.xlabel('N')
plt.ylabel('Qubit Quantity')

plt.show()

# %%
""" Valid Ratio """

x = [3, 4, 5, 6, 7, 8, 9]
simulator_no_noise = [1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00]
simulator_with_noise = [1.00, 0.98, 0.94, 0.93, 0.93, 0.90, 0.87]
brisbane = [1.00, 0.37, 0.22, 0.13, 0.04, 0.00, 0.00]
osaka = [1.00, 0.35, 0.18, 0.09, 0.01, 0.00, 0.00]
kyoto = [1.00, 0.30, 0.10, 0.07, 0.00, 0.00, 0.00]

plt.plot(x, simulator_no_noise, linestyle='-', linewidth=1, color='orange', label='simulator_no_noise')
plt.plot(x, simulator_with_noise, linestyle='-', linewidth=1, color='green', label='simulator_with_noise')
plt.plot(x, brisbane, linestyle='-', linewidth=1, color='blue', label='brisbane')
plt.plot(x, osaka, linestyle='-', linewidth=1, color='grey', label='osaka')
plt.plot(x, kyoto, linestyle='-', linewidth=1, color='red', label='kyoto')

plt.legend(['simulator_no_noise', 'simulator_with_noise', 'brisbane', 'osaka', 'kyoto'])
plt.xlabel('N')
plt.ylabel('Valid Ratio')

plt.show()

# %%
""" Optimal Ratio """

x = [3, 4, 5, 6, 7, 8, 9]
simulator_no_noise = [1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00]
simulator_with_noise = [1.00, 0.89, 0.85, 0.83, 0.82, 0.80, 0.80]
brisbane = [1.00, 0.03, 0.03, 0.02, 0.01, 0.00, 0.00]
osaka = [1.00, 0.02, 0.02, 0.00, 0.00, 0.00, 0.00]
kyoto = [1.00, 0.01, 0.01, 0.00, 0.00, 0.00, 0.00]

plt.plot(x, simulator_no_noise, linestyle='-', linewidth=1, color='orange', label='simulator_no_noise')
plt.plot(x, simulator_with_noise, linestyle='-', linewidth=1, color='green', label='simulator_with_noise')
plt.plot(x, brisbane, linestyle='-', linewidth=1, color='blue', label='brisbane')
plt.plot(x, osaka, linestyle='-', linewidth=1, color='grey', label='osaka')
plt.plot(x, kyoto, linestyle='-', linewidth=1, color='red', label='kyoto')

plt.legend(['simulator_no_noise', 'simulator_with_noise', 'brisbane', 'osaka', 'kyoto'])
plt.xlabel('N')
plt.ylabel('Optimal Ratio')

plt.show()

# %%
x = []
sqrt_log = []
y = []

for i in range(3, 50):
    x.append(i)
    y.append(i)
    sqrt_log.append(m.sqrt(i) * m.log2(i) )

plt.plot(x, sqrt_log, linestyle='-', linewidth=1, color='orange', label='simulator_no_noise')
plt.plot(x, y, linestyle='-', linewidth=1, color='blue', label='simulator_no_noise')
plt.show()

# %%
""" valid Ratio """

x = [4, 5, 6, 7]
brisbane = [0.0934, 0.0915, 0.0039, 0.0026]
osaka = [0.0835, 0.1038, 0.0036, 0.0029]
kyoto = [0.0866, 0.0892, 0.0037, 0.0023]

# x_values = np.arange(len(x))
plt.bar(np.array(x) - 0.2, brisbane, width=0.2, label='ibm_brisbane', color='#FA6800')
plt.bar(np.array(x), osaka, width=0.2, label='ibm_osaka', color='#76ADDC')
plt.bar(np.array(x) + 0.2, kyoto, width=0.2, label='ibm_kyoto', color='#CCE290')

plt.legend(['ibm_brisbane', 'ibm_osaka', 'ibm_kyoto'])
plt.xticks(range(4, 8))
plt.xlabel('N')
plt.ylabel('Valid Ratio')

plt.show()

# %%
""" Optimal Ratio """

x = [4, 5, 6, 7]
brisbane = [0.0354, 0.0091, 0.0001, 0.0000]
osaka = [0.0355, 0.0072, 0.0000, 0.0000]
kyoto = [0.0300, 0.0074, 0.0000, 0.0000]

plt.bar(np.array(x) - 0.2, brisbane, width=0.2, label='ibm_brisbane', color='#FA6800')
plt.bar(np.array(x), osaka, width=0.2, label='ibm_osaka', color='#76ADDC')
plt.bar(np.array(x) + 0.2, kyoto, width=0.2, label='ibm_kyoto', color='#CCE290')

plt.legend(['ibm_brisbane', 'ibm_osaka', 'ibm_kyoto'])
plt.xticks(range(4, 8))
plt.xlabel('N')
plt.ylabel('Optimal Ratio')

plt.show()

# %%
""" Circuit Depth """

x = [3, 4, 5, 6, 7]
simulator = [1193, 11062, 28617, 1229822, 8548452]
brisbane = [13517, 174332, 427203, 18123135, 125973307]
osaka = [14262, 169870, 427295, 17759765, 124126271]
kyoto = [14293, 173674, 415044, 17735470, 122986269]

solutions = [2, 6, 8, 15, 18]

qubit_num = [16, 20, 22, 29, 33]

max_iter_num = [45, 180, 360, 4073, 11520]

fig, ax1 = plt.subplots()

ax1.bar(np.array(x) - 0.3, simulator, width=0.2, label='Depth on simulator', color='#F8CECC')
ax1.bar(np.array(x) - 0.1, brisbane, width=0.2, label='Depth on ibm_brisbane', color='#FFE6CC')
ax1.bar(np.array(x) + 0.1, osaka, width=0.2, label='Depth on ibm_osaka', color='#6C8EBF')
ax1.bar(np.array(x) + 0.3, kyoto, width=0.2, label='Depth on ibm_kyoto', color='#D5E8D4')
ax1.set_ylabel('Average Circuit Depth (log)')
ax1.set_yscale('log')
ax1.set_xlabel('N')

ax2 = ax1.twinx()
ax2.plot(x, solutions, color='purple', linewidth=1, marker='o', markersize=3, label='TSP Solution')
ax2.set_ylabel('TSP Solutions (log2)')

# ax3 = ax1.twinx()
# ax3.plot(x, qubit_num, color='green', linewidth=1, marker='o', markersize=3, label='Number of Qubits')
# ax3.set_ylabel('Num of Qubits')
# ax3.spines['right'].set_position(('outward', 60))

# ax4 = ax1.twinx()
# ax4.plot(x, max_iter_num, color='orange', linewidth=1, marker='o', markersize=3, label='Maximum iteration of Grover')
# ax4.set_ylabel('Maximum iteration of Grover in QOPSA')
# ax4.spines['left'].set_position(('outward', 60))

bars, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars + lines2, labels1 + labels2, loc='upper left')

# ax1.legend(['ibm_brisbane', 'ibm_osaka', 'ibm_kyoto'])
# plt.xticks(range(4, 8))
# plt.xlabel('N')
# plt.ylabel('Optimal Ratio (log)')
# plt.yscale('log')

plt.show()

# %%
x = [3, 4, 5, 6, 7]
qubit_num = [16, 20, 22, 29, 33]
max_iter_num = [45, 180, 360, 4073, 11520]

fig, ax1 = plt.subplots()

ax1.bar(x, qubit_num, width=0.2, color='#F8CECC', label='Number of Qubits')
# ax2.plot(x, qubit_num, color='green', linewidth=1, marker='o', markersize=3, label='Number of Qubits')
ax1.set_ylabel('Number of Qubits')
ax1.set_yticks([10, 15, 20, 25, 30, 35, 40])
ax1.set_xlabel('N')
ax1.set_xticks(range(3, 8))

ax2 = ax1.twinx()
ax2.plot(x, max_iter_num, color='#6C8EBF', linewidth=1, marker='o', markersize=3, label='Maximum iterations of Grover')
ax2.set_ylabel('Maximum iterations of Grover in QOPSA (log)')
ax2.set_yscale('log')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# %%
""" precision """

x = [3, 4, 5, 6, 7]
# average_circuit_depth = [2269, 4249, 7558, 13546, 25565]
circuit_depth = [5896, 10599, 19486, 28617, 60921]
average_optimal_ratio = [0.4469, 0.7135, 0.7604, 0.9375, 1.00]
worst_case_optimal_ratio = [0.125, 0.125, 0.25, 0.5, 1.00]

qubit_num = [18, 18, 20, 22, 24]

fig, ax1 = plt.subplots()

ax1.bar(x, average_optimal_ratio, width=0.3, color='#6C8EBF', label='Average Opt. Ratio')
ax1.bar(x, worst_case_optimal_ratio, width=0.3, color='#FFE6CC', label='Worst-case Opt. Ratio')
ax1.set_ylabel('Opt. Ratio')
ax1.set_xlabel('Precision')

ax2 = ax1.twinx()
ax2.plot(x, circuit_depth, color='green', linewidth=1, marker='o', markersize=3, label='Circuit Depth')
ax2.set_ylabel('Circuit Depth')

ax3 = ax1.twinx()
ax3.plot(x, qubit_num, color='purple', linewidth=1, marker='s', markersize=3, label='Number of Qubits')
ax3.set_ylabel('Number of Qubits')
ax3.spines['right'].set_position(('outward', 60))
ax3.set_yticks([15, 18, 21, 24, 27])
# ax3.set_ylim(10, 30)

bars, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
ax1.legend(bars + lines2 + lines3, labels1 + labels2 + ['Number of Qubits'], loc='upper left')

plt.show()

# %%
test = [
    [1, 1],
    [9.5, 8.25],
    [10, 8],
    [10.25, 7.5],
    [10.25, 7],
    [1, 1]
]

x_values = [test[i][0] for i in range(len(test))]
y_values = [test[i][1] for i in range(len(test))]
plt.plot(x_values, y_values, color='#6C8EBF', linewidth=1, marker='o', markersize=3)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
ratio1 = 0.00002
ratio = 3 / 4 * ratio1
N = 15

failed_ratio = 1 - ratio
failed_ratio = failed_ratio ** m.floor(22.5 * m.sqrt(2 ** N))
success_ratio = 1 - failed_ratio
print(success_ratio)
# Out:
# 0.05925245403342849
