# %%
import matplotlib
import matplotlib.pyplot as plt

file_path = '../dataset/38/dj38.tsp'
with open(file_path, 'r') as file:
    lines = file.readlines()
lines = lines[10: -1]

points = []
for line in lines:
    point = line.strip().split(' ')[1:]
    points.append([float(point[i]) for i in range(len(point))])

# %matplotlib inline

for i in range(len(points)):
    plt.scatter(points[i][0], points[i][1])
    plt.text(points[i][0], points[i][1], str(i+1), fontsize=8, color='red')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

file_path = '../dataset/38/dj38.tsp'
with open(file_path, 'r') as file:
    lines = file.readlines()
lines = lines[10: -1]

points = []
for line in lines:
    point = line.strip().split(' ')[1:]
    points.append([float(point[i]) for i in range(len(point))])

# %matplotlib inline

for i in range(len(points)):
    if i == 15 or i == 16 or i == 17  or i == 18:
        plt.scatter(points[i][0], points[i][1])
        plt.text(points[i][0], points[i][1], str(i+1), fontsize=8, color='red')
plt.show()
